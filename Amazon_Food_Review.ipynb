# %%
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv("Amazon_rev.csv")

# %%
data.shape
# Out:
# (525814, 11)

# %% [markdown]
# # Visualizing Data

# %%
sns.pairplot(data)

# %%
dict={}
for i in data.columns:
    dict[i]=data[i].value_counts().shape[0]
    
pd.DataFrame(dict,index=['Unique']).T.style.background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_2319a_row0_col0, #T_2319a_row1_col0 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_2319a_row2_col0 {
#   background-color: #f4fbb7;
#   color: #000000;
# }
# #T_2319a_row3_col0 {
#   background-color: #88cd7f;
#   color: #000000;
# }
# #T_2319a_row4_col0 {
#   background-color: #a4d98a;
#   color: #000000;
# }
# #T_2319a_row5_col0, #T_2319a_row6_col0, #T_2319a_row7_col0 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_2319a_row8_col0 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_2319a_row9_col0 {
#   background-color: #70c275;
#   color: #000000;
# }
# #T_2319a_row10_col0 {
#   background-color: #30954f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2319a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2319a_level0_col0" class="col_heading level0 col0" >Unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
#Finding the duplicates from dataset...
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #  Table Normalization

# %%
data.head()
# Out:
#    Unnamed: 0  Id   ProductId          UserId  \
# 0           0   1  B001E4KFG0  A3SGXH7AUHU8GW
# 1           1   2  B00813GRG4  A1D87F6ZCVE5NK
# 2           2   3  B000LQOCH0   ABXLMWJIXXAIN
# 3           3   4  B000UA0QIQ  A395BORC6FGVXV
# 4           4   5  B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                        ProfileName  HelpfulnessNumerator  \
# 0                       delmartian                     1
# 1                           dll pa                     0
# 2  Natalia Corres "Natalia Corres"                     1
# 3                             Karl                     3
# 4    Michael D. Bigham "M. Wassir"                     0
#
#    HelpfulnessDenominator     Score        Time                Summary  \
# 0                       1  positive  1303862400  Good Quality Dog Food
# 1                       0  negative  1346976000      Not as Advertised
# 2                       1  positive  1219017600  "Delight" says it all
# ...

# %%
len(data.Summary.unique())
# Out:
# 271924

# %%
len(data.Summary)
# Out:
# 525814

# %%
data.head()
# Out:
#    Unnamed: 0  Id   ProductId          UserId  \
# 0           0   1  B001E4KFG0  A3SGXH7AUHU8GW
# 1           1   2  B00813GRG4  A1D87F6ZCVE5NK
# 2           2   3  B000LQOCH0   ABXLMWJIXXAIN
# 3           3   4  B000UA0QIQ  A395BORC6FGVXV
# 4           4   5  B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                        ProfileName  HelpfulnessNumerator  \
# 0                       delmartian                     1
# 1                           dll pa                     0
# 2  Natalia Corres "Natalia Corres"                     1
# 3                             Karl                     3
# 4    Michael D. Bigham "M. Wassir"                     0
#
#    HelpfulnessDenominator     Score        Time                Summary  \
# 0                       1  positive  1303862400  Good Quality Dog Food
# 1                       0  negative  1346976000      Not as Advertised
# 2                       1  positive  1219017600  "Delight" says it all
# ...

# %%
data.drop(data.columns[0], axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
data
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 525809  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 525810  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 525811  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 525812  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 525813  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %%
data['Text Length'] = list(map(lambda a : len(a.split()), data.Text))

# %%
data
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 525809  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 525810  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 525811  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 525812  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 525813  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %%
data.to_csv("norm3.csv", index=False)

# %%
data.drop(data.columns[-3:-1], axis =1, inplace = True)

# %%
data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator     Score        Time  \
# 0                     1                       1  positive  1303862400
# 1                     0                       0  negative  1346976000
# 2                     1                       1  positive  1219017600
# 3                     3                       3  negative  1307923200
# 4                     0                       0  positive  1350777600
#
#    Text Length
# 0           48
# 1           31
# 2           94
# 3           41
# 4           27

# %%
ser = pd.get_dummies(data.Score, drop_first=True)
ser
# Out:
#         positive
# 0              1
# 1              0
# 2              1
# 3              0
# 4              1
# ...          ...
# 525809         1
# 525810         0
# 525811         1
# 525812         1
# 525813         1
#
# [525814 rows x 1 columns]

# %%
data["Pos_Score"] = ser

# %%
data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator     Score        Time  \
# 0                     1                       1  positive  1303862400
# 1                     0                       0  negative  1346976000
# 2                     1                       1  positive  1219017600
# 3                     3                       3  negative  1307923200
# 4                     0                       0  positive  1350777600
#
#    Text Length  Pos_Score
# 0           48          1
# 1           31          0
# 2           94          1
# 3           41          0
# ...

# %%
# data = data.loc[:, ~data.columns.str.contains('^Unnamed')]

# %%
c= list(data.columns)

# %%
c
# Out:
# ['Id',
#  'ProductId',
#  'UserId',
#  'ProfileName',
#  'HelpfulnessNumerator',
#  'HelpfulnessDenominator',
#  'Score',
#  'Time',
#  'Text Length',
#  'Pos_Score']

# %%
c[6] = c[-1]

# %%
c
# Out:
# ['Id',
#  'ProductId',
#  'UserId',
#  'ProfileName',
#  'HelpfulnessNumerator',
#  'HelpfulnessDenominator',
#  'Pos_Score',
#  'Time',
#  'Text Length',
#  'Pos_Score']

# %%
c.pop()
# Out:
# 'Pos_Score'

# %%
data = data[c]

# %%
data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Pos_Score        Time  \
# 0                     1                       1          1  1303862400
# 1                     0                       0          0  1346976000
# 2                     1                       1          1  1219017600
# 3                     3                       3          0  1307923200
# 4                     0                       0          1  1350777600
#
#    Text Length
# 0           48
# 1           31
# 2           94
# 3           41
# 4           27

# %%
a = data[data["Pos_Score"] == 1]

column_count = a.count()
column_count['Pos_Score']
# Out:
# 443777

# %%
a = data[data["Pos_Score"] == 0]

column_count = a.count()
column_count['Pos_Score']
# Out:
# 82037

# %%
len(data.ProductId.unique())
# Out:
# 72005

# %%
test=pd.read_csv("norm3.csv")

# %%
lenght= len(test)
t= lenght*10/100
# Out:
# 52581.4

# %%
test = test.iloc[:52581]

# %%
len(test)
test.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Pos_Score        Time  \
# 0                     1                       1          1  1303862400
# 1                     0                       0          0  1346976000
# 2                     1                       1          1  1219017600
# 3                     3                       3          0  1307923200
# 4                     0                       0          1  1350777600
#
#    Text Length
# 0           48
# 1           31
# 2           94
# 3           41
# 4           27

# %% [markdown]
# # Model Fitting and Prediction

# %%
from sklearn.svm import  LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

# %%
features = ["HelpfulnessNumerator", "HelpfulnessDenominator", "Text Length"]
X_train = data[features] #define training features set
y_train = data["Pos_Score"] #define training label set
X_test = test[features] #define testing features set
Y_test = test["Pos_Score"]
#we don't have y_test, that is what we're trying to predict with our model

# %%
from sklearn.model_selection import train_test_split #to create validation data set

X_training, X_valid, y_training, y_valid = train_test_split(X_train, y_train, test_size=0.2, random_state=0) #X_valid and y_valid are the validation sets

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Using Decision Tree Classifier

# %%
dt_clf = DecisionTreeClassifier()
dt_clf.fit(X_training, y_training)
pred_dt = dt_clf.predict(X_valid)
acc_dt = accuracy_score(y_valid, pred_dt)

print(acc_dt)
# Out:
# 0.8693932276561148

# %%
pred_dt
# Out:
# array([1, 0, 1, ..., 1, 1, 1], dtype=uint8)

# %% [markdown]
# # Testing of Decesion Tree Classifier

# %%
dt_clf = DecisionTreeClassifier()
dt_clf.fit(X_training, y_training)
pred_dt = dt_clf.predict(X_test)
acc_dt = accuracy_score(Y_test, pred_dt)

print(acc_dt)
# Out:
# 0.8731861318727296

# %% [markdown]
# # Using Linear SVC

# %%
linsvc_clf = LinearSVC()
linsvc_clf.fit(X_training, y_training)
pred_linsvc = linsvc_clf.predict(X_valid)
acc_linsvc = accuracy_score(y_valid, pred_linsvc)

print(acc_linsvc)
# Out:
# 0.8547968391924916
# /home/saqib/.local/lib/python3.8/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %% [markdown]
# # Using GaussianNB

# %%
gnb_clf = GaussianNB()
gnb_clf.fit(X_training, y_training)
pred_gnb = gnb_clf.predict(X_valid)
acc_gnb = accuracy_score(y_valid, pred_gnb)

print(acc_gnb)
# Out:
# 0.8317469071821838

# %% [markdown]
# # Using Logistic Regression

# %%
logreg_clf = LogisticRegression()
logreg_clf.fit(X_training, y_training)
pred_logreg = logreg_clf.predict(X_valid)
acc_logreg = accuracy_score(y_valid, pred_logreg)

print(acc_logreg)
# Out:
# 0.8646387037265959

# %% [markdown]
# # Using Random Forest

# %%
rf_clf = RandomForestClassifier()
rf_clf.fit(X_training, y_training)
pred_rf = rf_clf.predict(X_valid)
acc_rf = accuracy_score(y_valid, pred_rf)

print(acc_rf)
# Out:
# 0.8708576210264066

# %% [markdown]
# # Using K nearest neighbour

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_clf = KNeighborsClassifier()
knn_clf.fit(X_training, y_training)
pred_knn = knn_clf.predict(X_valid)
acc_knn = accuracy_score(y_valid, pred_knn)

print(acc_knn)
# Out:
# 0.8626608217719159

# %%
model_performance = pd.DataFrame({
    "Model": [ "Linear SVC", "Random Forest", 
              "Logistic Regression", "K Nearest Neighbors", "Gaussian Naive Bayes",  
              "Decision Tree"],
    "Accuracy": [ acc_linsvc, acc_rf, 
              acc_logreg, acc_knn, acc_gnb, acc_dt]
})

model_performance.sort_values(by="Accuracy", ascending=False)
# Out:
#                   Model  Accuracy
# 5         Decision Tree  0.873186
# 1         Random Forest  0.870858
# 2   Logistic Regression  0.864639
# 3   K Nearest Neighbors  0.862661
# 0            Linear SVC  0.854797
# 4  Gaussian Naive Bayes  0.831747
